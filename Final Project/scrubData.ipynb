# %%
path = './data/Samsungtweets'

import pandas as pd
import numpy as np
import csv
# %matplotlib inline

lines = []
with open(path) as f:
    for line in f:
        lines.append(line)
        
Files = lines[0].split(')(')#.split('), (')
tweets = []
dataset = []
for File in Files:
    fileSplit = File.split('), (')
    for split in fileSplit:
        tweets.append(split)


print Files
'''
for tweet in tweets:
    
    tweetSplit = tweet.split(',')
    tail = len(tweetSplit) - 1  
    sentiment = tweetSplit[tail]
    tweetSplit.pop(tail)
    cleanTweet = ''.join(tweetSplit)
    tuples = [cleanTweet,sentiment]
    dataset.append(tuples)

myfile = open('samsungAnotatedTweets.csv', 'wb')
wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
wr.writerow(dataset)
'''
# Out:
# ['ArrayBuffer((Galaxy Note 7 Leather Sleeve | PUMPKIN |  |  Sleeve Pouch Etui,NEGATIVE), ( Galaxy Note 5 receiving  \xe2\x80\x99s Grace UX ,NEUTRAL), (@amber_peebles arriving this morning  Shot on      @samsungnz ,NEUTRAL), ( .@SamsungMobile, it\xe2\x80\x99s time to make the right decision for the planet and tell us your plan for the 4.3 million \xe2\x80\xa6,POSITIVE))ArrayBuffer((@iAm_erica:  Giving away a  and  Runs for 2 weeks! Thank you to @GetRhinoShield !,POSITIVE), (@SamsungMobileSA: Closing walls & ticking? Make the music yours with  & your . RT, guess the song name & you could\xe2\x80\xa6,NEUTRAL), (@SamsungMobileSA: Closing walls & ticking? Make the music yours with  & your . RT, guess the song name & you could\xe2\x80\xa6,NEUTRAL), (Want to get your hands on a Samsung  and Gear VR? Check out our Instagram comp for the chance to win:\xe2\x80\xa6 ,NEUTRAL), (@Samsung_Pak: Rock your  with the  and ! ,POSITIVE), (@SamsungMobileSA Clocks - Coldplay  ,NEUTRAL), (@SamsungMobileSA Clocks by Coldplay. ,NEGATIVE), (@SamsungMobileSA @SamsungSA   Clocks by Coldplay :),NEUTRAL), (@SamsungMobileSA: Closing walls & ticking? Make the music yours with  & your . RT, guess the song name & you could\xe2\x80\xa6,NEUTRAL), (@SamsungMobileSA: Closing walls & ticking? Make the music yours with  & your . RT, guess the song name & you could\xe2\x80\xa6,NEUTRAL), ( \xf0\x9f\x8e\x81 BLACK FRIDAYRT + Follow pour tenter de gagner un Samsung  \xf0\x9f\x93\xb1INCROYABLE \xe2\x9e\x94  ht\xe2\x80\xa6,NEGATIVE), (@VodafoneUK: Have you seen our competition to  a Samsung  and Gear VR over on Instagram? See here for more info: ,NEUTRAL))ArrayBuffer((@canpoyrazoglu: Finally, Amazon\xe2\x80\x99s \xe2\x80\x9cFire Phone\xe2\x80\x9d has a real competitor. ,POSITIVE), (@sprintcare I feel my bill has been crazy messed up for the last 3 months with @SamsungSupport  headaches!!!!  Please help!!!,NEGATIVE), (How is  like a  ? Answ:  Both could explode at any minute. At least  can\'t .  Transition,NEGATIVE), ( flight announcements still! Great advertisement for Samsung on every. single. flight.,POSITIVE), (@SamsungMobile Blow up phone  hasn\'t been replaced yet. Replacement mailed 3 wks ago. Cust Service clueless  @Samsung cc ,NEGATIVE), (@SamsungMobileUS @SamsungUS I miss my  :( :( :(,NEGATIVE), (Interested in joining lawsuit over the mishandling of the Note 7 recall? Contact Richard McClune Google him   @SamsungMobileUS,NEGATIVE))ArrayBuffer((Never knowingly beaten on valuations!    (32GB) - Valuation We always pay more tha  ,NEGATIVE), (Never knowingly beaten on valuations!    - Valuation We always pay more than any o  ,NEGATIVE), (  water now back on, please follow this link for advice for initial discoloration.  ^KT,NEGATIVE), (Never knowingly beaten on valuations! LG G5 - Valuation We always pay more than any othe    ,NEGATIVE), (sell  buy sell  buy sell  buy ,NEUTRAL))ArrayBuffer((Samsung might not be done with the Galaxy Note 7 ,NEGATIVE), (5 tech gifts you should definitely avoid this holiday season.  #1 Samsung Galaxy Note 7.  Ya think??  via ,NEGATIVE), (@amans143: Problem lies with the note, be it Samsung Galaxy "Note"7 or Indian currency "Note" of 500 & 1000.,NEGATIVE), (Updated: Samsung Galaxy Note 7 recall: what you need to\xc2\xa0know  ,NEGATIVE), (Samsung Galaxy Note 7 recall Update: While Samsung has yet to officially confirm that the replaced Galaxy Note 7... ,NEGATIVE), (With all the drama surrounding the Samsung Galaxy Note 7 you might think Samsung would bring the launch of the... ,NEGATIVE), (With the Galaxy Note 7 now officially unsafe for public use, Samsung could use a hit with its next handset, and... ,NEGATIVE))ArrayBuffer((Samsung might not be done with the Galaxy Note 7 ,NEGATIVE), (5 tech gifts you should definitely avoid this holiday season.  #1 Samsung Galaxy Note 7.  Ya think??  via ,NEGATIVE), (@amans143: Problem lies with the note, be it Samsung Galaxy "Note"7 or Indian currency "Note" of 500 & 1000.,NEGATIVE), (Updated: Samsung ...
# "\nfor tweet in tweets:\n    \n    tweetSplit = tweet.split(',')\n    tail = len(tweetSplit) - 1  \n    sentiment = tweetSplit[tail]\n    tweetSplit.pop(tail)\n    cleanTweet = ''.join(tweetSplit)\n    tuples = [cleanTweet,sentiment]\n    dataset.append(tuples)\n\nmyfile = open('samsungAnotatedTweets.csv', 'wb')\nwr = csv.writer(myfile, quoting=csv.QUOTE_ALL)\nwr.writerow(dataset)\n"
