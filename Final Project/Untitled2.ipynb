# %%
from sknn.mlp import Classifier, Layer
from  sklearn.cross_validation import train_test_split
from sklearn import preprocessing
import pandas as pd
import numpy as np
from gensim.models import word2vec
from nltk.corpus import stopwords
import nltk

data = pd.read_csv('final_output.csv')
# Out:
# /Users/lfawaz/miniconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/lfawaz/miniconda2/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
data
# Out:
#       Unnamed: 0                                           sentence  \
# 0              0  No reason to Risk of the high voltage wiring g...
# 1              1                           Oh to be stupid and smug
# 2              2  No water flood is an approved method of exting...
# 3              3  You would be lucky to feel a tingle before if ...
# 4              4  But if you wan na be a real lazy ass like me j...
# 5              5                               As do I Great cables
# 6              6                                  Note 7 is da bomb
# 7              7  Love my Note 5 Would happily buy Samsung espec...
# 8              8      Lucky that money runs like water in your home
# 9              9      and 96 of statistics are wrong 85 of the time
# 10            10  After this they will 100 be doing tons of test...
# 11            11  Good news but quite an obvious outcome I know ...
# 12            12                      best smartphone on the market
# 13            13  Plus Samsung is going to be extra desperate wi...
# 14            14  Can you imagine the pr nightmare if the 8 blow...
# 15            15  I like my V20 now but its nothing compared to ...
# 16            16  You got downvoted for not worshiping the corpo...
# 17            17  I would as well Im only using this LG V20 till...
# 18            18  Most people loved the curved screen on the Note 7
# 19            19  My s7e is my first Samsung phone And its firml...
# 20            20  People dont care GM had ignition issues people...
# 21            21  Bingo Im waiting for the note 8 I still love t...
# 22            22       And then hell try to sue Samsung for damages
# 23            23  I keep all my drone batteries in the fire plac...
# 24            24  Maybe Im really not sure at all what condition...
# 25            25  I dont charge at night anymore I charge in the...
# 26            26  What a world we live in where this is not just...
# 27            27  Well that might make it worse being enclosed a...
# 28            28                                         Looks good
# 29            29      Same here This bad boy hasnt blown up on me y
# ...          ...                                                ...
# 1918        1918  8005I got the 8005 error too I hope Samsung so...
# 1919        1919  Getting exactly this message I believe it is o...
# 1920        1920          This is a great at least its acknowledged
# 1921        1921  Having a simular problem Considering switching...
# 1922        1922  What the hell are you doing with it It sounds ...
# 1923        1923  I did it last night and it didnt really help I...
# 1924        1924  Cold only warm when I charge it with fast char...
# 1925        1925  My note 5 was having this issue I just called ...
# 1926        1926  Disable all Gear VR or anything related to VR ...
# 1927        1927           The battery is not removeable for the S7
# 1928        1928  Id say 2016 comes with interchangeable adapter...
# 1929        1929  2016 version is the way to go if you switch ph...
# 1930        1930  Just about any type of external mic you get sh...
# 1931        1931  Ill buy a thumb drive with like 500 GB storage...
# 1932        1932  It can run some new 2 5 inch drives via OTG bu...
# 1933        1933                Works with my WD 2TB external drive
# 1934        1934  I dont think it would provide enough power for...
# 1935        1935    Jesus Christ dude you are begging to get killed
# 1936        1936  My wife put hers in the ocean when went to PR ...
# 1937        1937  Pro tip Rice wont absorb the water and the dus...
# 1938        1938                                Good to know cheers
# 1939        1939  Yea I think what really matters is how deep yo...
# 1940        1940  I didnt even know this thing existed until tod...
